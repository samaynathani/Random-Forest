# %% [markdown]
# # Random Forest

# %% [markdown]
# ### Mastery Checkpoint 2
# CSC 466, Winter 2022
# Samay Nathani

# %%
from pathlib import Path
home = str(Path.home())

# %%
# %load_ext autoreload
# %autoreload 2

import random_forest

# %% [markdown]
# Import our dataset
# I chose the [Palantir Stock Price Dataset from Kaggle](https://www.kaggle.com/kalilurrahman/palantir-stock-data-latest-and-updated)

# %%
import pandas as pd
import numpy as np
import math
from scipy.stats import norm
from sklearn.model_selection import train_test_split

titanic_df = pd.read_csv(
    f"{home}/csc-466-student/data/titanic.csv"
)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
features = ['Pclass','Sex','Age','SibSp','Parch','Fare','Cabin','Embarked']
titanic_df2 = titanic_df.loc[:,features]
titanic_df2['CabinLetter'] = titanic_df2['Cabin'].str.slice(0,1)
X = titanic_df2.drop('Cabin',axis=1)#.dropna()
X['CabinLetter'] = X['CabinLetter'].fillna("?")
X['Pclass'] = X['Pclass'].astype(str)
X['SibSp'] = X['SibSp'].astype(str)
X['Parch'] = X['Parch'].astype(str)
X = X.dropna()
X.head()
# Out:
#   Pclass     Sex   Age SibSp Parch     Fare Embarked CabinLetter
# 0      3    male  22.0     1     0   7.2500        S           ?
# 1      1  female  38.0     1     0  71.2833        C           C
# 2      3  female  26.0     0     0   7.9250        S           ?
# 3      1  female  35.0     1     0  53.1000        S           C
# 4      3    male  35.0     0     0   8.0500        S           ?

# %%
t = titanic_df.loc[X.index,'Survived']
X2 = pd.get_dummies(X)

# %%
X_train, X_test, t_train, t_test = train_test_split(X2, t, test_size=0.3)

# %%
trees = random_forest.make_trees(X_train, t_train, n_features=20)

# %%
trees[0].predict(X_test)
# Out:
# Int64Index([ 40, 620, 249,   6, 861,  23, 360, 378, 188, 553,
#             ...
#             438, 672,  89, 191, 816, 872, 349, 407,  51, 703],
#            dtype='int64', length=214)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 40
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-d5bf21b2e966> in <module>
# ----> 1 trees[0][0].predict(X_test.loc[:,trees[0][1]])
#
# ~/Mastery Checkpoints/Random-Forest/random_forest.py in predict(self, X)
#     125         print(X.index)
#     126         for idx in X.index:
# --> 127             predict[idx] = X[idx]
#     128
#     129         for rule in self._rules:
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 40

# %%
pred = random_forest.vote(trees, X_test)

# %%
sum(t_test == pred) / len(pred)

# %%
airbnb_df = pd.read_csv(
    f"AB_NYC_2019.csv"
)
airbnb_df.head()

# %%
features = ["neighbourhood_group",  "room_type", "price", "number_of_reviews"]
airbnb = airbnb_df.loc[:, features]
airbnb["price"] = (airbnb["price"] // 100) * 100
airbnb["number_of_reviews"] = (airbnb["number_of_reviews"] // 100) * 100
airbnb.dropna(inplace=True)

# %%
X = airbnb.loc[:, ["price", "room_type", "number_of_reviews"]]
t = airbnb["neighbourhood_group"].astype("category").cat.codes
X2 = pd.get_dummies(X)
X_train, X_test, t_train, t_test = train_test_split(X2, t, test_size=0.3)
len(X2.columns)

# %%
dtr = random_forest.DecisionTreeRegressor()

# %%
trees = random_forest.make_trees(X_train, t_train, n_features=3)

# %%
pred = random_forest.vote(trees, X_test)

# %%
sum(t_test == pred) / len(pred)

# %%
#dtr.fit(X_train, t_train)

# %%
#dtr._rules
# Out:
# [[('price', 0.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Shared room', 0),
#   ('room_type_Entire home/apt', 0),
#   1],
#  [('price', 0.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Shared room', 0),
#   ('room_type_Entire home/apt', 1),
#   1],
#  [('price', 0.0), ('number_of_reviews', 0.0), ('room_type_Shared room', 1), 2],
#  [('price', 0.0),
#   ('number_of_reviews', 300.0),
#   ('room_type_Entire home/apt', 1),
#   3],
#  [('price', 0.0),
#   ('number_of_reviews', 300.0),
#   ('room_type_Entire home/apt', 0),
#   2],
#  [('price', 0.0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Entire home/apt', 0),
#   ('room_type_Private room', 1),
#   1],
#  [('price', 0.0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Entire home/apt', 0),
#   ('room_type_Private room', 0),
#   2],
#  [('price', 0.0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Entire home/apt', 1),
#   1],
#  [('price', 0.0),
#   ('number_of_reviews', 200.0),
#   ('room_type_Entire home/apt', 0),
#   ('room_type_Private room', 1),
#   1],
#  [('price', 0.0),
#   ('number_of_reviews', 200.0),
#   ('room_type_Entire home/apt', 0),
#   ('room_type_Private room', 0),
#   2],
#  [('price', 0.0),
#   ('number_of_reviews', 200.0),
#   ('room_type_Entire home/apt', 1),
#   1],
#  [('price', 0.0),
#   ('number_of_reviews', 400.0),
#   ('room_type_Private room', 1),
#   3],
#  [('price', 0.0),
#   ('number_of_reviews', 400.0),
#   ('room_type_Private room', 0),
#   3],
#  [('price', 0.0), ('number_of_reviews', 600.0), 2],
#  [('price', 0.0), ('number_of_reviews', 500.0), 3],
#  [('price', 300.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 1),
#   2],
#  [('price', 300.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 0),
#   ('room_type_Private room', 1),
#   2],
#  [('price', 300.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 0),
#   ('room_type_Private room', 0),
#   2],
#  [('price', 300.0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Entire home/apt', 1),
#   2],
#  [('price', 300.0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Entire home/apt', 0),
#   2],
#  [('price', 300.0), ('number_of_reviews', 200.0), 2],
#  [('price', 300.0), ('number_of_reviews', 300.0), 1],
#  [('price', 200.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 1),
#   2],
#  [('price', 200.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 0),
#   ('room_type_Private room', 1),
#   2],
#  [('price', 200.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 0),
#   ('room_type_Private room', 0),
#   2],
#  [('price', 200.0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Entire home/apt', 1),
#   2],
#  [('price', 200.0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Entire home/apt', 0),
#   ('room_type_Private room', 0),
#   2],
#  [('price', 200.0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Entire home/apt', 0),
#   ('room_type_Private room', 1),
#   2],
#  [('price', 200.0), ('number_of_reviews', 200.0), 1],
#  [('price', 200.0), ('number_of_reviews', 300.0), 1],
#  [('price', 200.0), ('number_of_reviews', 400.0), 1],
#  [('price', 100.0),
#   ('room_type_Entire home/apt', 1),
#   ('number_of_reviews', 0.0),
#   2],
#  [('price', 100.0),
#   ('room_type_Entire home/apt', 1),
#   ('number_of_reviews', 100.0),
#   1],
#  [('price', 100.0),
#   ('room_type_Entire home/apt', 1),
#   ('number_of_reviews', 200.0),
#   1],
#  [('price', 100.0),
#   ('room_type_Entire home/apt', 1),
#   ('number_of_reviews', 300.0),
#   1],
#  [('price', 100.0),
#   ('room_type_Entire home/apt', 1),
#   ('number_of_reviews', 400.0),
#   1],
#  [('price', 100.0),
#   ('room_type_Entire home/apt', 0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Private room', 1),
#   2],
#  [('price', 100.0),
#   ('room_type_Entire home/apt', 0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Private room', 0),
#   2],
#  [('price', 100.0),
#   ('room_type_Entire home/apt', 0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Private room', 1),
#   2],
#  [('price', 100.0),
#   ('room_type_Entire home/apt', 0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Private room', 0),
#   2],
#  [('price', 100.0),
#   ('room_type_Entire home/apt', 0),
#   ('number_of_reviews', 200.0),
#   2],
#  [('price', 100.0),
#   ('room_type_Entire home/apt', 0),
#   ('number_of_reviews', 300.0),
#   2],
#  [('price', 100.0),
#   ('room_type_Entire home/apt', 0),
#   ('number_of_reviews', 400.0),
#   2],
#  [('price', 400.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 1),
#   2],
#  [('price', 400.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 0),
#   ('room_type_Private room', 1),
#   2],
#  [('price', 400.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 0),
#   ('room_type_Private room', 0),
#   1],
#  [('price', 400.0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Entire home/apt', 1),
#   2],
#  [('price', 400.0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Entire home/apt', 0),
#   2],
#  [('price', 400.0), ('number_of_reviews', 200.0), 2],
#  [('price', 500.0),
#   ('room_type_Shared room', 0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 1),
#   2],
#  [('price', 500.0),
#   ('room_type_Shared room', 0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 0),
#   2],
#  [('price', 500.0),
#   ('room_type_Shared room', 0),
#   ('number_of_reviews', 100.0),
#   2],
#  [('price', 500.0),
#   ('room_type_Shared room', 0),
#   ('number_of_reviews', 400.0),
#   2],
#  [('price', 500.0),
#   ('room_type_Shared room', 0),
#   ('number_of_reviews', 200.0),
#   1],
#  [('price', 500.0), ('room_type_Shared room', 1), 2],
#  [('price', 700.0),
#   ('room_type_Shared room', 0),
#   ('room_type_Entire home/apt', 1),
#   ('number_of_reviews', 0.0),
#   2],
#  [('price', 700.0),
#   ('room_type_Shared room', 0),
#   ('room_type_Entire home/apt', 1),
#   ('number_of_reviews', 100.0),
#   2],
#  [('price', 700.0),
#   ('room_type_Shared room', 0),
#   ('room_type_Entire home/apt', 0),
#   2],
#  [('price', 700.0), ('room_type_Shared room', 1), 1],
#  [('price', 1500.0), ('room_type_Entire home/apt', 0), 2],
#  [('price', 1500.0), ('room_type_Entire home/apt', 1), 2],
#  [('price', 800.0),
#   ('room_type_Shared room', 0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 1),
#   2],
#  [('price', 800.0),
#   ('room_type_Shared room', 0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 0),
#   2],
#  [('price', 800.0),
#   ('room_type_Shared room', 0),
#   ('number_of_reviews', 100.0),
#   2],
#  [('price', 800.0), ('room_type_Shared room', 1), 0],
#  [('price', 600.0),
#   ('room_type_Entire home/apt', 1),
#   ('number_of_reviews', 0.0),
#   2],
#  [('price', 600.0),
#   ('room_type_Entire home/apt', 1),
#   ('number_of_reviews', 100.0),
#   2],
#  [('price', 600.0), ('room_type_Entire home/apt', 0), 2],
#  [('price', 1100.0), ('room_type_Entire home/apt', 1), 2],
#  [('price', 1100.0), ('room_type_Entire home/apt', 0), 1],
#  [('price', 1000.0),
#   ('room_type_Shared room', 0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 1),
#   2],
#  [('price', 1000.0),
#   ('room_type_Shared room', 0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 0),
#   1],
#  [('price', 1000.0),
#   ('room_type_Shared room', 0),
#   ('number_of_reviews', 100.0),
#   1],
#  [('price', 1000.0), ('room_type_Shared room', 1), 2],
#  [('price', 900.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 0),
#   2],
#  [('price', 900.0),
#   ('number_of_reviews', 0.0),
#   ('room_type_Entire home/apt', 1),
#   2],
#  [('price', 900.0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Entire home/apt', 0),
#   3],
#  [('price', 900.0),
#   ('number_of_reviews', 100.0),
#   ('room_type_Entire home/apt', 1),
#   1],
#  [('price', 2000.0), ('room_type_Entire home/apt', 1), 2],
#  [('price', 2000.0), ('room_type_Entire home/apt', 0), 1],
#  [('price', 5000.0), ('room_type_Entire home/apt', 1), 1],
#  [('price', 5000.0), ('room_type_Entire home/apt', 0), 1],
#  [('price', 7500.0), 2],
#  [('price', 1200.0),
#   ('room_type_Shared room', 0),
#   ('room_type_Entire home/apt', 1),
#   2],
#  [('price', 1200.0),
#   ('room_type_Shared room', 0),
#   ('room_type_Entire home/apt', 0),
#   2],
#  [('price', 1200.0), ('room_type_Shared room', 1), 3],
#  [('price', 9900.0), 2],
#  [('price', 3600.0), 2],
#  [('price', 1400.0), 2],
#  [('price', 2500.0), ('room_type_Entire home/apt', 1), 2],
#  [('price', 2500.0), ('room_type_Entire home/apt', 0), 0],
#  [('price', 1900.0), 2],
#  [('price', 3000.0), ('room_type_Entire home/apt', 0), 2],
#  [('price', 3000.0), ('room_type_Entire home/apt', 1), 2],
#  [('price', 1600.0), 1],
#  [('price', 2300.0), 3],
#  [('price', 6400.0), 2],
#  [('price', 1700.0), ('room_type_Entire home/apt', 1), 1],
#  [('price', 1700.0), ('room_type_Entire home/apt', 0), 2],
#  [('price', 10000.0), ('room_type_Entire home/apt', 0), 3],
#  [('price', 10000.0), ('room_type_Entire home/apt', 1), 1],
#  [('price', 4100.0), 2],
#  [('price', 2900.0), 2],
#  [('price', 4000.0), 2],
#  [('price', 2600.0), 1],
#  [('price', 1300.0), ('room_type_Entire home/apt', 1), 1],
#  [('price', 1300.0), ('room_type_Entire home/apt', 0), 2],
#  [('price', 5200.0), 2],
#  [('price', 3500.0), 2],
#  [('price', 2400.0), 2],
#  [('price', 3700.0), 2],
#  [('price', 6500.0), ('room_type_Entire home/apt', 0), 2],
#  [('price', 6500.0), ('room_type_Entire home/apt', 1), 1],
#  [('price', 3800.0), 2],
#  [('price', 6000.0), 2],
#  [('price', 2700.0), 2],
#  [('price', 2800.0), 2],
#  [('price', 7700.0), 2],
#  [('price', 8500.0), 2],
#  [('price', 1800.0), 2],
#  [('price', 4500.0), 1],
#  [('price', 2200.0), 2],
#  [('price', 3200.0), 2],
#  [('price', 5100.0), 2]]
